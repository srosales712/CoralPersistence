# %%
library(ggplot2)
library(microbiome)
library(phyloseq)
library("tidyverse")
library("dplyr")
library(vegan)
library("lubridate")
library("DESeq2")
library("GGally")
library("ggpmisc")
library(patchwork)

# %%
load("/Users/stephanie.rosales/Documents/omics_projects/POR_16S/CoralPersistence/data/POR_counts_4_analysis.RData")
load("/Users/stephanie.rosales/Documents/omics_projects/POR_16S/CoralPersistence/data/POR_taxo_4_analysis.RData")
## Need taxonomy and counts as matrices
taxo_mat <- as.matrix(POR_taxo_4_analysis)
count_mat <- as.matrix(POR_counts_4_analysis)

# %%
meta = read.csv ("/Users/stephanie.rosales/Documents/omics_projects/POR_16S/CoralPersistence/metadata/POR_combo_meta.csv",
row.names=1, header = T)%>%
  mutate(
    Month = factor(Month, levels = month.name)
  ) %>%
  arrange(Month) %>%
arrange(collection_date)

# %%
ASV <- otu_table(as.matrix(POR_counts_4_analysis), 
                 taxa_are_rows = T)
TAX <- tax_table(as.matrix(POR_taxo_4_analysis))
SAMP <- sample_data(meta)

ps <- phyloseq(ASV, TAX, SAMP)
ps
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 27534 taxa and 363 samples ]
# sample_data() Sample Data:       [ 363 samples by 54 sample variables ]
# tax_table()   Taxonomy Table:    [ 27534 taxa by 7 taxonomic ranks ]

# %%
ps_fill= filter_taxa(ps, function(x) sum(x > 0) > (0.0*length(x)), TRUE)
                     ps_fill
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 27507 taxa and 363 samples ]
# sample_data() Sample Data:       [ 363 samples by 54 sample variables ]
# tax_table()   Taxonomy Table:    [ 27507 taxa by 7 taxonomic ranks ]

# %%
(ps_fill_rare <- phyloseq::rarefy_even_depth(ps_fill, rngseed = 123, replace = FALSE, sample.size=1000))
# Out:
# `set.seed(123)` was used to initialize repeatable random subsampling.
#
# Please record this for your records so others can reproduce.
#
# Try `set.seed(123); .Random.seed` for the full vector
#
# ...
#
# 1 samples removedbecause they contained fewer reads than `sample.size`.
#
# Up to first five removed samples are:
#
#
# bagnumber-1759
#
# ...
#
# 17659OTUs were removed because they are no longer
# present in any sample after random subsampling
#
#
# ...
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 9848 taxa and 362 samples ]
# sample_data() Sample Data:       [ 362 samples by 54 sample variables ]
# tax_table()   Taxonomy Table:    [ 9848 taxa by 7 taxonomic ranks ]

# %%
adiv <- data.frame(
  "Shannon" = phyloseq::estimate_richness(ps_fill_rare, measures = "Shannon")) %>% rownames_to_column("sample_ID")
head(adiv)
# Out:
#   sample_ID      Shannon
# 1 bagnumber-1009 1.900643
# 2 bagnumber-1010 1.801524
# 3 bagnumber-1011 2.091382
# 4 bagnumber-1013 2.348979
# 5 bagnumber-1014 4.244923
# 6 bagnumber-1015 1.794133

# %%
#zscore
adiv_trans =adiv %>% 
  mutate(Shannon_trans = (Shannon - mean(Shannon))/sd(Shannon))
head(adiv_trans)
# Out:
#   sample_ID      Shannon  Shannon_trans
# 1 bagnumber-1009 1.900643 -0.59742689
# 2 bagnumber-1010 1.801524 -0.72100072
# 3 bagnumber-1011 2.091382 -0.35962843
# 4 bagnumber-1013 2.348979 -0.03847617
# 5 bagnumber-1014 4.244923  2.32523793
# 6 bagnumber-1015 1.794133 -0.73021507

# %%
adiv_trans =adiv %>%
mutate(Shannon_trans = log10(Shannon))
head(adiv_trans)
# Out:
#   sample_ID      Shannon  Shannon_trans
# 1 bagnumber-1009 1.900643 0.2789005
# 2 bagnumber-1010 1.801524 0.2556400
# 3 bagnumber-1011 2.091382 0.3204334
# 4 bagnumber-1013 2.348979 0.3708792
# 5 bagnumber-1014 4.244923 0.6278698
# 6 bagnumber-1015 1.794133 0.2538546

# %%
qqnorm(adiv_trans$Shannon_trans)
qqline(adiv_trans$Shannon_trans)
shapiro.test(adiv_trans$Shannon_trans)
hist(adiv_trans$Shannon_trans, col='steelblue', main='shannon')
# Out:
# 	Shapiro-Wilk normality test
#
# data:  adiv_trans$Shannon_trans
# W = 0.94159, p-value = 9.623e-11
# Plot with title “Normal Q-Q Plot”
# Plot with title “shannon”

# %%
qqnorm(adiv$Shannon)
qqline(adiv$Shannon)
shapiro.test(adiv$Shannon)
hist(adiv$Shannon, col='steelblue', main='shannon')
# Out:
# 	Shapiro-Wilk normality test
#
# data:  adiv$Shannon
# W = 0.82974, p-value < 2.2e-16
# Plot with title “Normal Q-Q Plot”
# Plot with title “shannon”

# %%
ps_ra_meta= as(sample_data(ps_fill_rare), "data.frame")
ps_ra_meta_envs = ps_ra_meta %>% select("Genotype", "Samp_trip", "reef",'Speed.cm.s.', 'NO2.uM.', 'N.N.uM.', 'NO3.uM.', 'PO4.uM.', 'Si.uM.',
                "Speed.cm.s.", "avgSST_degC", "avgchla_mgm.3","LiveFrag", "Temperature.C.")

# %%
head(ps_ra_meta_envs)
# Out:
#                Genotype Samp_trip reef Speed.cm.s. NO2.uM. N.N.uM. NO3.uM.
# bagnumber-1009 ML2      Trip_3    cf   4.852118    0.032   0.893   0.861
# bagnumber-1010 ML2      Trip_3    cf   4.852118    0.032   0.893   0.861
# bagnumber-1011 ML2      Trip_3    cf   4.852118    0.032   0.893   0.861
# bagnumber-1013 CN4      Trip_3    cf   4.852118    0.032   0.893   0.861
# bagnumber-1014 CN4      Trip_3    cf   4.852118    0.032   0.893   0.861
# bagnumber-1015 CN4      Trip_3    cf   4.852118    0.032   0.893   0.861
#                PO4.uM. Si.uM. avgSST_degC avgchla_mgm.3 LiveFrag Temperature.C.
# bagnumber-1009 0.0685  0.706  29.63623    1.792092      0.5      30.40801
# bagnumber-1010 0.0685  0.706  29.63623    1.792092      0.5      30.40801
# bagnumber-1011 0.0685  0.706  29.63623    1.792092      0.5      30.40801
# bagnumber-1013 0.0685  0.706  29.63623    1.792092      1.0      30.40801
# bagnumber-1014 0.0685  0.706  29.63623    1.792092      0.5      30.40801
# bagnumber-1015 0.0685  0.706  29.63623    1.792092      0.5      30.40801

# %%
names(ps_ra_meta_envs[4:12])
# Out:
# [1] "Speed.cm.s."   "NO2.uM."       "N.N.uM."       "NO3.uM."
# [5] "PO4.uM."       "Si.uM."        "avgSST_degC"   "avgchla_mgm.3"
# [9] "LiveFrag"

# %%
dim(adiv_trans)
head(adiv_trans)
# Out:
# [1] 362   3
#   sample_ID      Shannon  Shannon_trans
# 1 bagnumber-1009 1.900643 0.2789005
# 2 bagnumber-1010 1.801524 0.2556400
# 3 bagnumber-1011 2.091382 0.3204334
# 4 bagnumber-1013 2.348979 0.3708792
# 5 bagnumber-1014 4.244923 0.6278698
# 6 bagnumber-1015 1.794133 0.2538546

# %%
#adiv_trans %>% left_join(ps_ra_meta_envs)
alpha_envs=cbind(ps_ra_meta_envs, adiv_trans)

# %%
head(alpha_envs)
# Out:
#                Genotype Samp_trip reef Speed.cm.s. NO2.uM. N.N.uM. NO3.uM.
# bagnumber-1009 ML2      Trip_3    cf   4.852118    0.032   0.893   0.861
# bagnumber-1010 ML2      Trip_3    cf   4.852118    0.032   0.893   0.861
# bagnumber-1011 ML2      Trip_3    cf   4.852118    0.032   0.893   0.861
# bagnumber-1013 CN4      Trip_3    cf   4.852118    0.032   0.893   0.861
# bagnumber-1014 CN4      Trip_3    cf   4.852118    0.032   0.893   0.861
# bagnumber-1015 CN4      Trip_3    cf   4.852118    0.032   0.893   0.861
#                PO4.uM. Si.uM. avgSST_degC avgchla_mgm.3 LiveFrag Temperature.C.
# bagnumber-1009 0.0685  0.706  29.63623    1.792092      0.5      30.40801
# bagnumber-1010 0.0685  0.706  29.63623    1.792092      0.5      30.40801
# bagnumber-1011 0.0685  0.706  29.63623    1.792092      0.5      30.40801
# bagnumber-1013 0.0685  0.706  29.63623    1.792092      1.0      30.40801
# bagnumber-1014 0.0685  0.706  29.63623    1.792092      0.5      30.40801
# bagnumber-1015 0.0685  0.706  29.63623    1.792092      0.5      30.40801
#                sample_ID      Shannon  Genotype Shannon_trans
# bagnumber-1009 bagnumber-1009 1.900643 ML2      0.2789005
# bagnumber-1010 bagnumber-1010 1.801524 ML2      0.2556400
# bagnumber-1011 bagnumber-1011 2.091382 ML2      0.3204334
# bagnumber-1013 bagnumber-1013 2.348979 CN4      0.3708792
# bagnumber-1014 bagnumber-1014 4.244923 CN4      0.6278698
# bagnumber-1015 bagnumber-1015 1.794133 CN4      0.2538546

# %%
y_columns <- names(ps_ra_meta_envs[4:12])

# %%
# Create an empty list to store the plots
plots <- list()

# Loop through each y variable and create a plot
for (y_var in y_columns) {
  plot <- alpha_envs %>%
    ggplot(aes( x = .data[[y_var]], y = Shannon_trans, color = Samp_trip)) +
    geom_point(alpha = 0.6) +
    theme_bw() +
    geom_smooth(method = 'lm', color = 'black') +
    
    stat_poly_eq(
      formula = y ~ x,
      eq.with.lhs = "italic(hat(y))~`=`~",
      aes(label = paste(..rr.label.., ..p.value.label.., sep = "~~~")),
      parse = TRUE,
      label.y = "bottom",
      label.x = "right",
      color = "black",
      rr.digits = 3,
      size = 2
    ) +
    
    stat_poly_eq(
      aes(label = paste(..eq.label.., sep = "~~~")),
      label.y = 0.15,
      eq.with.lhs = "italic(hat(y))~`=`~",
      eq.x.rhs = "~italic(x)",
      formula = y ~ x,
      parse = TRUE,
      size = 2,
      label.x = "right",
      color = "black"
    )
  
  # Add the plot to the list
  plots[[y_var]] <- plot
}

# Combine all plots into a single plot
combined_plot <- wrap_plots(plots)

# Print the combined plot
print(combined_plot)
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# Create an empty list to store the plots
plots <- list()

# Loop through each y variable and create a plot
for (y_var in y_columns) {
  plot <- alpha_envs %>%
    ggplot(aes( x = .data[[y_var]], y = Shannon_trans, color = Genotype)) +
    geom_point(alpha = 0.6) +
    theme_bw() +
    geom_smooth(method = 'lm', color = 'black') +
    
    stat_poly_eq(
      formula = y ~ x,
      eq.with.lhs = "italic(hat(y))~`=`~",
      aes(label = paste(..rr.label.., ..p.value.label.., sep = "~~~")),
      parse = TRUE,
      label.y = "bottom",
      label.x = "right",
      color = "black",
      rr.digits = 3,
      size = 2
    ) +
    
    stat_poly_eq(
      aes(label = paste(..eq.label.., sep = "~~~")),
      label.y = 0.15,
      eq.with.lhs = "italic(hat(y))~`=`~",
      eq.x.rhs = "~italic(x)",
      formula = y ~ x,
      parse = TRUE,
      size = 2,
      label.x = "right",
      color = "black"
    )
  
  # Add the plot to the list
  plots[[y_var]] <- plot
}

# Combine all plots into a single plot
combined_plot <- wrap_plots(plots)

# Print the combined plot
print(combined_plot)
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# Create an empty list to store the plots
plots <- list()

# Loop through each y variable and create a plot
for (y_var in y_columns) {
  plot <- alpha_envs %>%
    ggplot(aes( x = .data[[y_var]], y = Shannon_trans, color = reef)) +
    geom_point(alpha = 0.6) +
    theme_bw() +
    geom_smooth(method = 'lm', color = 'black') +
    
    stat_poly_eq(
      formula = y ~ x,
      eq.with.lhs = "italic(hat(y))~`=`~",
      aes(label = paste(..rr.label.., ..p.value.label.., sep = "~~~")),
      parse = TRUE,
      label.y = "bottom",
      label.x = "right",
      color = "black",
      rr.digits = 3,
      size = 2
    ) +
    
    stat_poly_eq(
      aes(label = paste(..eq.label.., sep = "~~~")),
      label.y = 0.15,
      eq.with.lhs = "italic(hat(y))~`=`~",
      eq.x.rhs = "~italic(x)",
      formula = y ~ x,
      parse = TRUE,
      size = 2,
      label.x = "right",
      color = "black"
    )
  
  # Add the plot to the list
  plots[[y_var]] <- plot
}

# Combine all plots into a single plot
combined_plot <- wrap_plots(plots)

# Print the combined plot
print(combined_plot)
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
